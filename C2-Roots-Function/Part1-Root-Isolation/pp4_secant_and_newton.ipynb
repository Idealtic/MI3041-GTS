# %% [markdown]
# $x_0: f(x_0) \cdot f''(x_0) > 0$
#
# $x_1: f(x_0) \cdot f(x_1) < 0$
#
# $x_2 = x_0 - \dfrac{f(x_0)}{f'(x_0)}$
#
# $x_3 = x_1 - \dfrac{f(x_0)(x_1-x_0)}{f(x_1)-f(x_0)}$
#
# ...
#
# $x_{2k}, x_{2k+1}$
#
# $x_{2k+2} = x_{2k} - \dfrac{f(x_{2k})}{f'(x_{2k})}$
#
# $x_{2k+3} = x_{2k+1} - \dfrac{f(x_{2k+1})(x_{2k+1}-x_{2k})}{f(x_{2k+1})-f(x_{2k})}$
#
# $|x_{2k+3} - x^{*}| \leqslant |x_{2k+3} - x_{2k+1}|$
